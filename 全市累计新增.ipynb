# %% [markdown]
# 全市累计新增（确诊、⽆症状、死亡病例）折线统计图
# 使用数据集：cumulative.csv
# 相对路径：CaseInfo\cumulative.csv
#
# 导入模块

# %%
import plotly.graph_objs as go
import plotly.io as pio
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt
import plotly.offline as py

from pyecharts.charts import *
from pyecharts.components import Table
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode
from pyecharts.globals import CurrentConfig
CurrentConfig.ONLINE_HOST = "https://cdn.kesci.com/lib/pyecharts_assets/"

# %% [markdown]
# 数据预处理

# %%
date_list = pd.date_range(start='2022-02-27', end='2022-06-04')
date_str_list = [str(i.year)+str(i.month).zfill(2)+str(i.day).zfill(2) for i in date_list]

# %%
 df = pd.read_csv('EstimateRt\processed.csv').fillna(0)#处理空值为0
 df_city = pd.DataFrame(df)
 df_city
# Out:
#     Unnamed: 0          时间  总数  确诊  无症状  无症状转归   死亡    累计总数
# 0            0  2022-02-27   1   0    1    0.0  0.0       1
# 1            1  2022-02-28   3   0    3    0.0  0.0       4
# 2            2  2022-03-01   2   1    1    0.0  0.0       6
# 3            3  2022-03-02   0   0    0    0.0  0.0       6
# 4            4  2022-03-03  16   2   14    0.0  0.0      22
# ..         ...         ...  ..  ..  ...    ...  ...     ...
# 93          93  2022-05-31  15   5   10    1.0  0.0  648787
# 94          94  2022-06-01  13   5    8    3.0  0.0  648800
# 95          95  2022-06-02  16   8    8    2.0  0.0  648816
# 96          96  2022-06-03  14   5    9    2.0  0.0  648830
# 97          97  2022-06-04  22   6   16    1.0  0.0  648852
#
# [98 rows x 8 columns]

# %% [markdown]
# 绘制折线图

# %%
# 将图表改为 Pyecharts
dates = df['时间'].tolist()
date_sum = df['总数'].tolist()
quezhen = df['确诊'].tolist()
wuzhengzhuang = df['无症状'].tolist()
zhuangui = df['无症状转归'].tolist()
dead = df['死亡'].tolist()
all_sum = df['累计总数'].tolist()
line = (Line()
        .add_xaxis(dates)
        .add_yaxis('当日确诊',quezhen)
        .add_yaxis('当日感染者总数',date_sum)
        .add_yaxis('当日无症状',wuzhengzhuang)
        .add_yaxis('当日无症状转归',zhuangui)
        .add_yaxis('当日死亡',dead)
        .add_yaxis('累计感染者总数',all_sum)
        .set_global_opts(
            # title_opts=opts.TitleOpts(title="上海全市疫情折线统计图"),
            datazoom_opts=[opts.DataZoomOpts(orient = 'vertical',range_start = 0,range_end = 100,type_="inside"),opts.DataZoomOpts()],
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        )
# line.render('上海全市疫情折线统计图.html')
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://cdn.kesci.com/lib/pyecharts_assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="56160a72bb8f47558f9bb3db62412d59" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_56160a72bb8f47558f9bb3db62412d59 = echarts.init(
#                     document.getElementById('56160a72bb8f47558f9bb3db62412d59'), 'white', {renderer: 'canvas'});
#                 var option_56160a72bb8f47558f9bb3db62412d59 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
