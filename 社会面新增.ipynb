# %%
import pandas as pd
import matplotlib.pyplot as plt
import pyecharts.charts as pyc

data = pd.read_csv('social_screening.csv')
df = pd.DataFrame(data)

df_quezhen = df.loc[:,~df.columns.str.contains('wuzhengzhuang')] 
df_wuzhengzhuang = df.loc[:,~df.columns.str.contains('quezhen')] 

date_list = list(df_quezhen)
date = []
for string in date_list:
    length = len(string)
    string = string[0:length-8]
    date.append(string)
del date[0]

districts = df['address'].tolist()

line_quezhen = pyc.Line()
line_quezhen.add_xaxis(date)
for district in districts:
    index = df_quezhen[(df_quezhen['address']==district)].index.tolist()[0]
    data_list = df_quezhen.values.tolist()[index]
    del data_list[0]
    line_quezhen.add_yaxis(district,data_list)
line_quezhen.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b5cac594e65344a0815f58ad8e3f25b2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b5cac594e65344a0815f58ad8e3f25b2 = echarts.init(
#                     document.getElementById('b5cac594e65344a0815f58ad8e3f25b2'), 'white', {renderer: 'canvas'});
#                 var option_b5cac594e65344a0815f58ad8e3f25b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "Shanghai",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2022-03-27",
#                     33
#                 ],
#                 [
#                     "2022-03-28",
#                     68
#                 ],
#                 [
#                     "2022-03-29",
#                     291
#                 ],
#                 [
#                     "2022-03-30",
#                     329
#                 ],
#                 [
#                     "2022-03-31",
#                     330
#                 ],
#                 [
#                     "2022-04-01",
#                     250
#                 ],
#                 [
#                     "2022-04-02",
#                     349
#                 ],
#                 [
#                     "2022-04-03",
#                     347
#                 ],
#                 [
#                     "2022-04-04",
#                     250
#                 ],
#                 [
#                     "2022-04-05",
#                     267
#                 ],
#                 [
#                     "2022-04-06",
#                     295
#                 ],
#                 [
#                     "2022-04-07",
#                     380
#                 ],
#                 [
#                     "2022-04-08",
#                     294
#                 ],
#                 [
#                     "2022-04-09",
#                     587
#                 ],
#                 [
#                     "2022-04-10",
#                     303
#                 ],
#                 [
#                     "2022-04-11",
#                     282
#                 ],
#                 [
#                     "2022-04-12",
#                     299
#                 ],
#                 [
#                     "2022-04-13",
#                     259
#                 ],
#                 [
#                     "2022-04-14",
#                     346
#                 ],
#                 [
#                     "2022-04-15",
#                     357
#                 ],
#                 [
#                     "2022-04-16",
#                     307
#                 ],
#                 [
#                     "2022-04-17",
#                     155
#                 ],
#                 [
#                     "2022-04-18",
#                     216
#                 ],
#                 [
#                     "2022-04-19",
#                     161
#                 ],
#                 [
#                     "2022-04-20",
#                     199
#                 ],
#                 [
#                     "2022-04-21",
#                     103
#                 ],
#                 [
#                     "2022-04-22",
#                     74
#                 ],
#                 [
#                     "2022-04-23",
#                     44
#                 ],
#                 [
#                     "2022-04-24",
#                     69
#                 ],
#                 [
#                     "2022-04-25",
#                     18
#                 ],
#                 [
#                     "2022-04-26",
#                     13
#                 ],
#                 [
#                     "2022-04-27",
#                     2
#                 ],
#                 [
#                     "2022-04-28",
#                     7
#                 ],
#                 [
#                     "2022-04-29",
#                     0
#                 ],
#                 [
#                     "2022-04-30",
#                     0
#                 ],
#                 [
#                     "2022-05-01",
#                     0
#                 ],
#                 [
#                     "2022-05-02",
#                     2
#                 ],
#                 [
#                     "2022-05-03",
#                     1
#                 ],
#                 [
#                     "2022-05-04",
#                     1
#                 ],
#                 [
#                     "2022-05-05",
#                     0
#                 ],
#                 [
#                     "2022-05-06",
#                     0
#                 ],
#                 [
#                     "2022-05-07",
#                     0
#                 ],
#                 [
#                     "2022-05-08",
#                     0
#                 ],
#                 [
#                     "2022-05-09",
#                     0
#                 ],
#                 [
#                     "2022-05-10",
#                     0
#                 ],
#                 [
#                     "2022-05-11",
#                     0
#                 ],
#                 [
#                     "2022-05-12",
#                     0
#                 ],
#                 [
#                     "2022-05-13",
#                     0
#                 ],
#                 [
#                     "2022-05-14",
#                     0
#                 ],
#                 [
#                     "2022-05-15",
#                     0
#                 ],
#                 [
#                     "2022-05-16",
#                     0
#                 ],
#                 [
#                     "2022-05-17",
#                     0
#                 ],
#                 [
#                     "2022-05-18",
#                     0
#                 ],
#                 [
#                     "2022-05-19",
#                     0
#                 ],
#                 [
#                     "2022-05-20",
#                     0
#                 ],
#                 [
#                     "2022-05-21",
#                     0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "PudongNew",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2022-03-27",
#                     2
#                 ],
#                 [
#                     "2022-03-28",
#                     33
#                 ],
#                 [
#                     "2022-03-29",
#                     162
#                 ],
#                 [
#                     "2022-03-30",
#                     246
#                 ],
#                 [

# %%
line_wuzhengzhuang = pyc.Line()
line_wuzhengzhuang.add_xaxis(date)
for district in districts:
    index = df_wuzhengzhuang[(df_wuzhengzhuang['address']==district)].index.tolist()[0]
    data_list = df_wuzhengzhuang.values.tolist()[index]
    del data_list[0]
    line_wuzhengzhuang.add_yaxis(district,data_list)
line_wuzhengzhuang.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0f94da053ced445da62116461bc17c21" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0f94da053ced445da62116461bc17c21 = echarts.init(
#                     document.getElementById('0f94da053ced445da62116461bc17c21'), 'white', {renderer: 'canvas'});
#                 var option_0f94da053ced445da62116461bc17c21 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "Shanghai",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2022-03-27",
#                     617
#                 ],
#                 [
#                     "2022-03-28",
#                     557
#                 ],
#                 [
#                     "2022-03-29",
#                     525
#                 ],
#                 [
#                     "2022-03-30",
#                     821
#                 ],
#                 [
#                     "2022-03-31",
#                     434
#                 ],
#                 [
#                     "2022-04-01",
#                     649
#                 ],
#                 [
#                     "2022-04-02",
#                     1015
#                 ],
#                 [
#                     "2022-04-03",
#                     661
#                 ],
#                 [
#                     "2022-04-04",
#                     494
#                 ],
#                 [
#                     "2022-04-05",
#                     510
#                 ],
#                 [
#                     "2022-04-06",
#                     633
#                 ],
#                 [
#                     "2022-04-07",
#                     600
#                 ],
#                 [
#                     "2022-04-08",
#                     756
#                 ],
#                 [
#                     "2022-04-09",
#                     525
#                 ],
#                 [
#                     "2022-04-10",
#                     943
#                 ],
#                 [
#                     "2022-04-11",
#                     504
#                 ],
#                 [
#                     "2022-04-12",
#                     641
#                 ],
#                 [
#                     "2022-04-13",
#                     598
#                 ],
#                 [
#                     "2022-04-14",
#                     378
#                 ],
#                 [
#                     "2022-04-15",
#                     495
#                 ],
#                 [
#                     "2022-04-16",
#                     415
#                 ],
#                 [
#                     "2022-04-17",
#                     406
#                 ],
#                 [
#                     "2022-04-18",
#                     334
#                 ],
#                 [
#                     "2022-04-19",
#                     229
#                 ],
#                 [
#                     "2022-04-20",
#                     242
#                 ],
#                 [
#                     "2022-04-21",
#                     147
#                 ],
#                 [
#                     "2022-04-22",
#                     144
#                 ],
#                 [
#                     "2022-04-23",
#                     236
#                 ],
#                 [
#                     "2022-04-24",
#                     148
#                 ],
#                 [
#                     "2022-04-25",
#                     199
#                 ],
#                 [
#                     "2022-04-26",
#                     158
#                 ],
#                 [
#                     "2022-04-27",
#                     190
#                 ],
#                 [
#                     "2022-04-28",
#                     101
#                 ],
#                 [
#                     "2022-04-29",
#                     0
#                 ],
#                 [
#                     "2022-04-30",
#                     0
#                 ],
#                 [
#                     "2022-05-01",
#                     58
#                 ],
#                 [
#                     "2022-05-02",
#                     71
#                 ],
#                 [
#                     "2022-05-03",
#                     62
#                 ],
#                 [
#                     "2022-05-04",
#                     33
#                 ],
#                 [
#                     "2022-05-05",
#                     23
#                 ],
#                 [
#                     "2022-05-06",
#                     18
#                 ],
#                 [
#                     "2022-05-07",
#                     11
#                 ],
#                 [
#                     "2022-05-08",
#                     9
#                 ],
#                 [
#                     "2022-05-09",
#                     5
#                 ],
#                 [
#                     "2022-05-10",
#                     0
#                 ],
#                 [
#                     "2022-05-11",
#                     2
#                 ],
#                 [
#                     "2022-05-12",
#                     4
#                 ],
#                 [
#                     "2022-05-13",
#                     1
#                 ],
#                 [
#                     "2022-05-14",
#                     0
#                 ],
#                 [
#                     "2022-05-15",
#                     0
#                 ],
#                 [
#                     "2022-05-16",
#                     0
#                 ],
#                 [
#                     "2022-05-17",
#                     0
#                 ],
#                 [
#                     "2022-05-18",
#                     0
#                 ],
#                 [
#                     "2022-05-19",
#                     3
#                 ],
#                 [
#                     "2022-05-20",
#                     0
#                 ],
#                 [
#                     "2022-05-21",
#                     0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "PudongNew",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2022-03-27",
#                     422
#                 ],
#                 [
#                     "2022-03-28",
#                     367
#                 ],
#                 [
#                     "2022-03-29",
#                     192
#                 ],
#                 [
#                     "2022-03-30",
#                     298
